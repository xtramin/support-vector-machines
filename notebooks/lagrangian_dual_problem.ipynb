# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score

# %%
def gradient_ascent(X, y, learning_rate, n_iters):
    n_samples, n_features = X.shape
    alpha = np.zeros(n_samples)
    for _ in range(n_iters):
        K = X @ X.T
        gradient = 1 - K @ (alpha * y) * y
        alpha += learning_rate * gradient
        alpha = np.clip(alpha, 0, 1)
        alpha = alpha - np.mean(alpha * y) * y
    return alpha

# %%
X, y = make_classification(n_samples=1000, n_features=4, class_sep=1.5)
alpha = gradient_ascent(X, y, 0.01, 100)
accuracy_score(y, np.sign(np.sum(alpha * y * (X @ X.T), axis=0)))
# Out:
# 0.933

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.show()
